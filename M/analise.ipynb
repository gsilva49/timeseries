# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
series = pd.read_csv('2000_2021_Brazilian_Northeast_Region_daily_MW_instantaneous_maximum_demand_series.csv - 2000_2021_Brazilian_Northeast_Region_daily_MW_instantaneous_maximum_demand_series_train.csv',
                    index_col='data', parse_dates=['data'],
                  squeeze=True)

# %%
series.plot()
plt.xticks(rotation=45)
plt.xlabel('Data')
plt.ylabel('Energia')
plt.tight_layout()
#plt.show()
