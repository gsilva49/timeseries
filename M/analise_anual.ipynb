# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
def yearly_lineplot(series, years):
    series['ano'] =[d.strftime('%Y') for d in series.index]
    series['mes_dia'] = [d.strftime('%b-%d') for d in series.index]

    anos = df['ano'].unique()
    mes_dia = df['mes_dia'].unique()
    
    count = 0
    for i, a in enumerate(anos):

        plt.plot('mes_dia','energia', data=series.loc[series.ano==a,:], label=a)
        plt.legend(bbox_to_anchor=(1,1), loc="upper left")
        count = count + 1
        if count == years:
            break
            
    plt.xticks(mes_dia[::30], mes_dia[::30], rotation='vertical')

    plt.show()

# %%
def yearly_boxplot(series):
    series['ano'] = [d.strftime('%Y') for d in series.index]
    sns.boxplot(x='ano', y='energia', data=series)

# %%
df = pd.read_csv('2000_2021_Brazilian_Northeast_Region_daily_MW_instantaneous_maximum_demand_series.csv - 2000_2021_Brazilian_Northeast_Region_daily_MW_instantaneous_maximum_demand_series_train.csv', parse_dates=['data'], index_col='data')

# %%
yearly_lineplot(df,2)

# %%
yearly_boxplot(df)
